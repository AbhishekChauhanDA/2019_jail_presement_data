# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\91977\OneDrive\Desktop\prtc\209 jial presement\2019 CITYBISE jial prsement.csv")
df.head()
# Out:
#   S. No                    City   Juveniles Apprehended - Boys  \
# 0     1     Ahmedabad (Gujarat)                            298
# 1     2    Bengaluru(Karnataka)                            197
# 2     3     Chennai(Tamil Nadu)                            816
# 3     4  Coimbatore(Tamil Nadu)                             35
# 4     5                  Delhi                            3073
#
#     Juveniles Apprehended - Girls   Juveniles Apprehended - Total  \
# 0                               0                             298
# 1                               3                             200
# 2                               0                             816
# 3                               0                              35
# 4                               2                            3075
#
#    18 and above and below 30 years - Male  \
# 0                                   14488
# 1                                   13577
# 2                                   13717
# ...

# %%
df.shape
# Out:
# (20, 20)

# %%
df.describe()
# Out:
#         Juveniles Apprehended - Boys   Juveniles Apprehended - Girls  \
# count                      20.000000                       20.000000
# mean                      779.000000                        1.600000
# std                      1782.633622                        3.719083
# min                         0.000000                        0.000000
# 25%                        24.250000                        0.000000
# 50%                       286.500000                        0.000000
# 75%                       486.750000                        2.000000
# max                      7790.000000                       16.000000
#
#         Juveniles Apprehended - Total  18 and above and below 30 years - Male  \
# count                       20.000000                               20.000000
# mean                       780.600000                            20142.200000
# std                       1785.900787                            44281.912065
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 20 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   S. No                                            20 non-null     object
#  1   City                                             20 non-null     object
#  2    Juveniles Apprehended - Boys                    20 non-null     int64
#  3    Juveniles Apprehended - Girls                   20 non-null     int64
#  4    Juveniles Apprehended - Total                   20 non-null     int64
#  5   18 and above and below 30 years - Male           20 non-null     int64
#  6   18 and above and below 30 years - Female         20 non-null     int64
#  7   18 and above and below 30 years - Total          20 non-null     int64
#  8   30 and above and below 45 years - Male           20 non-null     int64
# ...

# %%
df.isnull().sum()
# Out:
# S. No                                              0
# City                                               0
#  Juveniles Apprehended - Boys                      0
#  Juveniles Apprehended - Girls                     0
#  Juveniles Apprehended - Total                     0
# 18 and above and below 30 years - Male             0
# 18 and above and below 30 years - Female           0
# 18 and above and below 30 years - Total            0
# 30 and above and below 45 years - Male             0
# 30 and above and below 45 years - Female           0
# 30 and above and below 45 years - Total            0
# 45 and above and below 60 years - Male             0
# 45 and above and below 60 years - Female           0
# 45 and above and below 60 years - Total            0
# 60 years and above - Male                          0
# 60 years and above - Female                        0
# 60 years and above - Total                         0
# Total   - Male                                     0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
droping_total =df.iloc[:-1,:]
df=droping_total

# %%
df.tail()
# Out:
#    S. No                 City   Juveniles Apprehended - Boys  \
# 14    15  Mumbai(Maharashtra)                            668
# 15    16  Nagpur(Maharashtra)                            442
# 16    17         Patna(Bihar)                             15
# 17    18    Pune(Maharashtra)                            420
# 18    19       Surat(Gujarat)                            621
#
#      Juveniles Apprehended - Girls   Juveniles Apprehended - Total  \
# 14                               0                             668
# 15                               2                             444
# 16                               0                              15
# 17                               0                             420
# 18                               2                             623
#
#     18 and above and below 30 years - Male  \
# 14                                   26772
# 15                                    4918
# 16                                    4480
# ...

# %%
plt.figure(figsize=(9,7))
barfig=sns.barplot(data=df,x=df["Total   - Total Persons Arrested by age and Sex"],y=df["City"])
barfig.bar_label(barfig.containers[0])
plt.xlabel("Total person arrested by age and sex")
plt.show()

# %%
df.columns = df.columns.str.strip().str.replace(" ","")

# %%
df.columns
# Out:
# Index(['S.No', 'City', 'JuvenilesApprehended-Boys',
#        'JuvenilesApprehended-Girls', 'JuvenilesApprehended-Total',
#        '18andaboveandbelow30years-Male', '18andaboveandbelow30years-Female',
#        '18andaboveandbelow30years-Total', '30andaboveandbelow45years-Male',
#        '30andaboveandbelow45years-Female', '30andaboveandbelow45years-Total',
#        '45andaboveandbelow60years-Male', '45andaboveandbelow60years-Female',
#        '45andaboveandbelow60years-Total', '60yearsandabove-Male',
#        '60yearsandabove-Female', '60yearsandabove-Total', 'Total-Male',
#        'Total-Female', 'Total-TotalPersonsArrestedbyageandSex'],
#       dtype='object')

# %%
sns.histplot(data=df[['JuvenilesApprehended-Total',
       '18andaboveandbelow30years-Total', '30andaboveandbelow45years-Total',  '45andaboveandbelow60years-Total',
       '60yearsandabove-Total']],bins=5)
plt.show()

# %%
sns.boxplot(data=df[['Total-Male',
       'Total-Female', 'Total-TotalPersonsArrestedbyageandSex']])
plt.xticks(rotation=10)
plt.show()
